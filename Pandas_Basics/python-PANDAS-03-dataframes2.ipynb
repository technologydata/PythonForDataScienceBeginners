# %% [markdown]
# <b>This file will guide you:
# <li>How to load data into pandas dataframe
# <li>Handling missing values
# <li>Data Cleaning
# <li>handling Duplicates
# </b>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the dataset

# %%
df = pd.read_csv('pandas_ex1.csv')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# # Change the column name in the dataframe while reading from the file

# %%
# overriding the column names
df= pd.read_csv('pandas_ex1.csv', 
             names=['Col1', 'Col2', 'Col3', 'Col4', 'message'])
df
# Out:
#   Col1 Col2 Col3 Col4  message
# 0    a    b    c    d  message
# 1    1    2    3    4    hello
# 2    5    6    7    8    world
# 3    9   10   11   12      foo

# %% [markdown]
# # Donot consider first line as header

# %%
# No headers
df= pd.read_csv('pandas_ex1.csv', 
             header= None)
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %% [markdown]
# # Setting index while reading

# %%
# Suppose you wanted the message column to be the index
names = ['Col1', 'Col2', 'Col3', 'Col4', 'message']
df= pd.read_csv('pandas_ex1.csv', 
                 names= names, index_col= 'message')
df
# Out:
#         Col1 Col2 Col3 Col4
# message
# message    a    b    c    d
# hello      1    2    3    4
# world      5    6    7    8
# foo        9   10   11   12

# %% [markdown]
# # Handling missing values

# %% [markdown]
# <b>
# <li>Missing data is usually either not present (empty string) or marked by some sentinel value.
# <li>By default, pandas uses a set of commonly occurring sentinels, such as NA and NULL
# </b>

# %%
df = pd.read_csv('pandas_ex2.csv')
df
# Out:
#   something    a     b     c      d message
# 0       one  1.0   2.0   3.0      4     NaN
# 1       two  5.0   6.0   NaN      8   world
# 2     three  9.0  10.0  11.0     12     foo
# 3      four  NaN   NaN   4.0  Globe     NaN
# 4      five  NaN   NaN   NaN    NaN   Earth

# %% [markdown]
# <b>Check if the value is null or not at every location in the whole dataframe </b>

# %%
pd.isnull(df)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False
# 3      False   True   True  False  False     True
# 4      False   True   True   True   True    False

# %% [markdown]
# <b>Check if the value is null or not in a particular column  </b>

# %%
pd.isnull(df['a'])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: a, dtype: bool

# %% [markdown]
# <b>Setting your own defination of NULL values along with pandas defaults</b>

# %%
# Different NA sentinels can be specified for each column in a dict:
sentinels = {'message': ['foo', 'NA'], 'something': ['two', 'three']}
df = pd.read_csv('pandas_ex3.csv', 
                 nrows=7)
df
# Out:
#   something    a     b     c      d message
# 0       one  1.0   2.0   3.0      4     NaN
# 1       two  5.0   6.0   NaN      8   world
# 2     three  9.0  10.0  11.0     12     foo
# 3      four  NaN   NaN   4.0  Globe     NaN
# 4      five  NaN   NaN   NaN    NaN   Earth

# %% [markdown]
# <b>Using na_values to tell which values can represent NULL</b>

# %%
# Different NA sentinels can be specified for each column in a dict:
sentinels = {'message': ['foo', 'NA'], 'something': ['two', 'three']}
df = pd.read_csv('pandas_ex3.csv', 
                 na_values=sentinels, nrows=7)
df
# Out:
#   something    a     b     c      d message
# 0       one  1.0   2.0   3.0      4     NaN
# 1       NaN  5.0   6.0   NaN      8   world
# 2       NaN  9.0  10.0  11.0     12     NaN
# 3      four  NaN   NaN   4.0  Globe     NaN
# 4      five  NaN   NaN   NaN    NaN   Earth

# %% [markdown]
# # Data Cleaning and Preparation

# %%
from numpy import nan as NA
df = pd.DataFrame([[1., 6.5, 3.], 
                     [1.,NA ,NA ],
                     [NA,NA ,NA ], 
                     [NA, 6.5, 3.]])
df
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %% [markdown]
# <b> dropna by default drops any row containing a missing value </b>

# %%
df.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %% [markdown]
# <b> Passing <u>how='all'</u> will only drop rows that are all NA</b>

# %%
df.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df
# Out:
#           0         1         2
# 0  0.767005 -1.138071 -1.772745
# 1  0.905906 -0.819671  0.617198
# 2 -0.380238 -0.636597 -1.463878
# 3 -0.544569  1.669116  0.042881
# 4  2.156335  1.047597 -0.631609
# 5  1.846102 -0.342013  0.226454
# 6 -0.165501  1.474794  0.971966

# %% [markdown]
# <b>Set some values to NULL</b>

# %%
# upto first 3 rows and col  = 1
df.iloc[:4, 1] = NA
df
# Out:
#           0         1         2
# 0  0.767005       NaN -1.772745
# 1  0.905906       NaN  0.617198
# 2 -0.380238       NaN -1.463878
# 3 -0.544569       NaN  0.042881
# 4  2.156335  1.047597 -0.631609
# 5  1.846102 -0.342013  0.226454
# 6 -0.165501  1.474794  0.971966

# %%
df.iloc[:2, 2] = NA
df
# Out:
#           0         1         2
# 0  0.767005       NaN       NaN
# 1  0.905906       NaN       NaN
# 2 -0.380238       NaN -1.463878
# 3 -0.544569       NaN  0.042881
# 4  2.156335  1.047597 -0.631609
# 5  1.846102 -0.342013  0.226454
# 6 -0.165501  1.474794  0.971966

# %%
df.dropna()
# Out:
#           0         1         2
# 4  2.156335  1.047597 -0.631609
# 5  1.846102 -0.342013  0.226454
# 6 -0.165501  1.474794  0.971966

# %% [markdown]
# # Filling In Missing Data

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0  0.767005  0.000000  0.000000
# 1  0.905906  0.000000  0.000000
# 2 -0.380238  0.000000 -1.463878
# 3 -0.544569  0.000000  0.042881
# 4  2.156335  1.047597 -0.631609
# 5  1.846102 -0.342013  0.226454
# 6 -0.165501  1.474794  0.971966

# %% [markdown]
# <b>fillna returns a new object, but you can modify the existing object in-place</b>

# %%
df
# Out:
#           0         1         2
# 0  0.767005       NaN       NaN
# 1  0.905906       NaN       NaN
# 2 -0.380238       NaN -1.463878
# 3 -0.544569       NaN  0.042881
# 4  2.156335  1.047597 -0.631609
# 5  1.846102 -0.342013  0.226454
# 6 -0.165501  1.474794  0.971966

# %%
df.fillna(0, inplace=True)
df
# Out:
#           0         1         2
# 0  0.767005  0.000000  0.000000
# 1  0.905906  0.000000  0.000000
# 2 -0.380238  0.000000 -1.463878
# 3 -0.544569  0.000000  0.042881
# 4  2.156335  1.047597 -0.631609
# 5  1.846102 -0.342013  0.226454
# 6 -0.165501  1.474794  0.971966

# %% [markdown]
# # Interpolation methods

# %%
df = pd.DataFrame(np.random.randn(6, 3))
df
# Out:
#           0         1         2
# 0  1.417462  0.270978 -0.505738
# 1  0.500109  1.495455  1.074341
# 2  0.366289 -0.644213 -0.099480
# 3  0.625595 -1.808797 -0.654506
# 4 -0.299085 -1.021130  0.764471
# 5 -0.263008  0.443690  0.507892

# %%
df.iloc[2:, 1] = NA
df.iloc[4:, 2] = NA
df
# Out:
#           0         1         2
# 0  1.417462  0.270978 -0.505738
# 1  0.500109  1.495455  1.074341
# 2  0.366289       NaN -0.099480
# 3  0.625595       NaN -0.654506
# 4 -0.299085       NaN       NaN
# 5 -0.263008       NaN       NaN

# %%
df.fillna(method='ffill')
# Out:
#           0         1         2
# 0  1.417462  0.270978 -0.505738
# 1  0.500109  1.495455  1.074341
# 2  0.366289  1.495455 -0.099480
# 3  0.625595  1.495455 -0.654506
# 4 -0.299085  1.495455 -0.654506
# 5 -0.263008  1.495455 -0.654506

# %% [markdown]
# # Removing Duplicates

# %%
df = pd.DataFrame([[1,3],
                  [3,4],
                  [1,3],
                  [5,7],
                  [6,9],
                  [5,7],
                  [1,3]])
                
df
# Out:
#    0  1
# 0  1  3
# 1  3  4
# 2  1  3
# 3  5  7
# 4  6  9
# 5  5  7
# 6  1  3

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %% [markdown]
# <b>drop_duplicates returns a DataFrame where the duplicated array is False</b>

# %%
df.drop_duplicates()
# Out:
#    0  1
# 0  1  3
# 1  3  4
# 3  5  7
# 4  6  9

# %% [markdown]
# <b>
# <li>duplicated and drop_duplicates by default keep the first observed value combination.
# <li>Passing keep='last' will return the last one
#
# </b>

# %%
df.drop_duplicates(keep='last')
# Out:
#    0  1
# 1  3  4
# 4  6  9
# 5  5  7
# 6  1  3

# %% [markdown]
# # Thank You.Happy Coding !!!
